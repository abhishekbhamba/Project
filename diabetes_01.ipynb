# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("diabetes.csv")
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df1 = df.head(10)
df1
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
# 5            5      116             74              0        0  25.6
# 6            3       78             50             32       88  31.0
# 7           10      115              0              0        0  35.3
# 8            2      197             70             45      543  30.5
# 9            8      125             96              0        0   0.0
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# ...

# %% [markdown]
# #    Pima Indians Diabetes Database Descriptive Statistics PROJECT

# %% [markdown]
# # (i) Missing values, number of rows and columns and data types in statistical          term:-

# %%
# missing values.
df1.isnull()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin    BMI  \
# 0        False    False          False          False    False  False
# 1        False    False          False          False    False  False
# 2        False    False          False          False    False  False
# 3        False    False          False          False    False  False
# 4        False    False          False          False    False  False
# 5        False    False          False          False    False  False
# 6        False    False          False          False    False  False
# 7        False    False          False          False    False  False
# 8        False    False          False          False    False  False
# 9        False    False          False          False    False  False
#
#    DiabetesPedigreeFunction    Age  Outcome
# 0                     False  False    False
# 1                     False  False    False
# 2                     False  False    False
# ...

# %%
# number of rows and columns with datatype.
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               10 non-null     int64
#  1   Glucose                   10 non-null     int64
#  2   BloodPressure             10 non-null     int64
#  3   SkinThickness             10 non-null     int64
#  4   Insulin                   10 non-null     int64
#  5   BMI                       10 non-null     float64
#  6   DiabetesPedigreeFunction  10 non-null     float64
#  7   Age                       10 non-null     int64
#  8   Outcome                   10 non-null     int64
# dtypes: float64(2), int64(7)
# memory usage: 848.0 bytes

# %% [markdown]
# # (ii) Central tendency for Glucose and outcome column only:-

# %%
# assigned a new name for Glucose and Outcome
df2 = df1[["Glucose","Outcome"]]
df2
# Out:
#    Glucose  Outcome
# 0      148        1
# 1       85        0
# 2      183        1
# 3       89        0
# 4      137        1
# 5      116        0
# 6       78        1
# 7      115        0
# 8      197        1
# 9      125        1

# %%
# mean of the glucose and outcome.
df2.mean()
# Out:
# Glucose    127.3
# Outcome      0.6
# dtype: float64

# %%
# median of glucose and outcome.
df2.median()
# Out:
# Glucose    120.5
# Outcome      1.0
# dtype: float64

# %%
# mode of the glucose and outcome.
df2.mode()
# Out:
#    Glucose  Outcome
# 0       78      1.0
# 1       85      NaN
# 2       89      NaN
# 3      115      NaN
# 4      116      NaN
# 5      125      NaN
# 6      137      NaN
# 7      148      NaN
# 8      183      NaN
# 9      197      NaN

# %% [markdown]
# # (iii) Provide 5 points data summaries for required columns:-

# %%
# this is the summary of data.
"""In this we can see all the count, max, min etc"""
df1.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count     10.00000   10.000000      10.000000      10.000000   10.000000
# mean       4.40000  127.300000      59.800000      19.900000   89.300000
# std        3.50238   40.075068      25.654976      17.978073  169.937276
# min        0.00000   78.000000       0.000000       0.000000    0.000000
# 25%        1.25000   95.500000      53.500000       0.000000    0.000000
# 50%        4.00000  120.500000      66.000000      26.000000    0.000000
# 75%        7.50000  145.250000      71.500000      34.250000   92.500000
# max       10.00000  197.000000      96.000000      45.000000  543.000000
#
#              BMI  DiabetesPedigreeFunction        Age    Outcome
# count  10.000000                 10.000000  10.000000  10.000000
# mean   27.710000                  0.507800  35.900000   0.600000
# std    11.259016                  0.654114  11.873874   0.516398
# ...

# %% [markdown]
# # (iv) Plot to examine the relationship between Age and Glucose:-

# %%
# i have assigned a new name here.
df3 = df1[["Age","Glucose"]]
df3
# Out:
#    Age  Glucose
# 0   50      148
# 1   31       85
# 2   32      183
# 3   21       89
# 4   33      137
# 5   30      116
# 6   26       78
# 7   29      115
# 8   53      197
# 9   54      125

# %%
# here is the sorting of the values in assending order.
df4 = df3.sort_values("Age")
df4
# Out:
#    Age  Glucose
# 3   21       89
# 6   26       78
# 7   29      115
# 5   30      116
# 1   31       85
# 2   32      183
# 4   33      137
# 0   50      148
# 8   53      197
# 9   54      125

# %%
# here is the histogram plot for comparison of two columns.
bin_edges = [0,10,20,30,40,50,60,70]

plt.hist(df4["Age"],bins=bin_edges)
plt.xlabel('AGE')
plt.ylabel('GLUCOSE')
plt.show()

# %% [markdown]
# # (v) Create an appropriate plot to see the distribution of Outcome variable:-

# %%
# calling a previous table. 
df1
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
# 5            5      116             74              0        0  25.6
# 6            3       78             50             32       88  31.0
# 7           10      115              0              0        0  35.3
# 8            2      197             70             45      543  30.5
# 9            8      125             96              0        0   0.0
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# ...

# %%
# here i have taken some important columns to see the output.
df5 = df1[["Glucose","BloodPressure","SkinThickness","Insulin","Outcome"]]
df5
# Out:
#    Glucose  BloodPressure  SkinThickness  Insulin  Outcome
# 0      148             72             35        0        1
# 1       85             66             29        0        0
# 2      183             64              0        0        1
# 3       89             66             23       94        0
# 4      137             40             35      168        1
# 5      116             74              0        0        0
# 6       78             50             32       88        1
# 7      115              0              0        0        0
# 8      197             70             45      543        1
# 9      125             96              0        0        1

# %%
# here is showing the outcome variable
sns.pairplot(df5,hue="Outcome")

# %% [markdown]
# # (vi) Examine the distribution of numerical data and explain which variable normally distributed and which variable is seems to be skewed:-

# %%
df1
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
# 5            5      116             74              0        0  25.6
# 6            3       78             50             32       88  31.0
# 7           10      115              0              0        0  35.3
# 8            2      197             70             45      543  30.5
# 9            8      125             96              0        0   0.0
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# ...

# %%
# Insuline and DiabetesPedigreeFunction number is 2 which is higher and it is making skew toward the right side.
df6 = df1.skew()
df6
# Out:
# Pregnancies                 0.300262
# Glucose                     0.574433
# BloodPressure              -1.388613
# SkinThickness              -0.149827
# Insulin                     2.535941
# BMI                        -1.657161
# DiabetesPedigreeFunction    2.700589
# Age                         0.723420
# Outcome                    -0.484123
# dtype: float64

# %%
# here is the normally distributed variable.

from matplotlib.pyplot import figure
import statistics

figure(figsize=(20,5))

x_axis = df6
mean = statistics.mean(x_axis)
sd = statistics.stdev(x_axis)
plt.plot(x_axis)
plt.show()

# %% [markdown]
# # (vii) Calculate the skewness value and divide variables into symmetrical, moderately skewed and highly skewed:-

# %%
df1
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
# 5            5      116             74              0        0  25.6
# 6            3       78             50             32       88  31.0
# 7           10      115              0              0        0  35.3
# 8            2      197             70             45      543  30.5
# 9            8      125             96              0        0   0.0
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# ...

# %%
# here is the skewness of all columns with variable into moderately, symmetrically, highly skewed.
from scipy.stats import skew

for col in df1:
    print(col)
    print(skew(df1[col]))
    
    plt.figure()
    sns.distplot(df1[col])
    plt.show()
# Out:
# Pregnancies
# 0.253202854044525
# C:\anaconda\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Glucose
# 0.48440484910495724
# C:\anaconda\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# BloodPressure
# -1.1709809689746424
# ...

# %% [markdown]
# # (viii) Plot to examine the outliers of these variables. Please name the variables which have outliers:-

# %%
# this is table name.
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
# here i have taken different ages to find diabetic problem.

"""age group people facing problem is 21,22,24,25,26,27,28,etc"""

sns.set_style("whitegrid")
plt.rcParams["figure.figsize"]=[25,11]
sns.boxplot(x="Age",y="DiabetesPedigreeFunction",data=df)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='DiabetesPedigreeFunction'>

# %% [markdown]
# # (ix) Measures of central tendency and dispersion for skewed data:-

# %%
# this is the skew data. which i have assigned with name.
df8 = df1.skew()
df8
# Out:
# Pregnancies                 0.300262
# Glucose                     0.574433
# BloodPressure              -1.388613
# SkinThickness              -0.149827
# Insulin                     2.535941
# BMI                        -1.657161
# DiabetesPedigreeFunction    2.700589
# Age                         0.723420
# Outcome                    -0.484123
# dtype: float64

# %% [raw]
# CENTRAL TENDENCY OF SKEWED DATA---(MEAN, MEDIAN, MODE)

# %%
df8.mean()
# Out:
# 0.3505469574383349

# %%
df8.median()
# Out:
# 0.3002616483134536

# %%
df8.mode()
# Out:
# 0   -1.657161
# 1   -1.388613
# 2   -0.484123
# 3   -0.149827
# 4    0.300262
# 5    0.574433
# 6    0.723420
# 7    2.535941
# 8    2.700589
# dtype: float64

# %% [raw]
# DISPERSION FOR SKEWED DATA----(VARIANCE, STANDAR DEVIATION)

# %%
df8.std()
# Out:
# 1.5204006982973475

# %%
df8.var()
# Out:
# 2.311618283383062
